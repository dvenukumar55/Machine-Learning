# %%
from sklearn.metrics import precision_score

y_actual = [1, 0, 1, 0, 0, 1]
y_pred   = [1, 1, 1, 0, 0, 1]

precision = precision_score(y_actual, y_pred)
print("Precision:", precision)
# Out:
# Precision: 0.75
